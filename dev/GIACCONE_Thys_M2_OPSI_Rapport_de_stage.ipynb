# %% [markdown]
# <p>&nbsp; </p>
# <p>&nbsp; </p>
# <h1><center>Exploration
# du codage prédictif
# grâce au jeu vidéo</center></h1>
# <p>&nbsp; </p>
#
# ___
#
# <center>**Encadrants : Bruno Wicker, Laurent Perrinet**
# *Laboratoire de Neurosciences Cognitives, Equipe ACDC, UMR 7291 CNRS
# 3, place Victor-Hugo 13331 - Marseille Cedex 3*
# *Ecole Centrale Marseille, Technopôle de Château-Gombert
# 38, rue Frédéric Joliot Curie 13451 - Marseille Cedex 20*</center>
#
# <p>&nbsp; </p>
#
# <p style="text-align:justify";>**Abstract:** Nous nous intéressons à l'influence du contexte perceptuel sur les mécanismes de prise de décision via un apprentissage probabiliste. La capacité à générer des prédictions est centrale pour des systèmes adaptatifs et intelligents comme le cerveau. Celui-ci génère continuellement des prédictions sur quelles données il va recevoir par la suite en se basant sur les données actuelles et les associations de données apprises par le passé. Plus précisément, on décrit ces phénomènes grâce à un modèle hiérarchique d'inférence Bayésienne permettant de modéliser prédictions et calcul d'erreur.</p>
# ___
#
# ## Références
# <small><small><small>
# 1. Colin J. Palmer, Rebecca P. Lawson and Jakob Hohwy, *"Bayesian Approaches to Autism: Towards Volatility, Action and Behavior"*, ResearchGate (2017)
# 2. Karl Friston, Rick A. Adams, Laurent Perrinet and Michael Breakspear, *"Perceptions as hypotheses: saccades as experiments"*, edited by Lars Muckli, University of Glasgow, UK (2012)
# 3. Meltem Sevgi, Andrea O. Diaconescu, Marc Tittgemeyer and Leonhard Schilbach, *"Social Bayes: Using Bayesian Modeling to Study Autistic Trait-Related Differences in Social Cognition"*, Society of Biological Psychiatry (2016)
# 4. Christian Keysers and Valeria Gazzola, *"Hebbian learning and predictive neurons for actions, sensations and emotions"*, Philosophical Transactions of the Royal Society (2014)
# 5. Karl Friston, Jérémie Mattout and James Kilner, *"Action understanding and active inference"*, Europe PMC Funders Group (2012)
# 6. Catherine Manning, James Kilner, Louise Neil, Themelis Karaminis and Elizabeth Pellicano, *"Children on the autism spectrum update their behaviour in response to a volatile environment"*, Developmental Science (2016)
# 7. Florent Meyniel, Maxime Maheu and Stanislas Dehaene, *"Human Inferences about Sequences: A Minimal Transition Probability Model"*, PLOS Computational Biology (2016)
# 8. Benjamin T. Vincent, *"Bayesian accounts of covert selective attention: A tutorial review"*, Atten Percept Psychophys (2015)</small></small></small>
# ___
#
# ## 1. Introduction
# * Depuis plusieurs années, notre compréhension du fonctionnement du cerveau s'est affinée. Son développement
# Contexte : développement/prédiction
# * importance du traitement du signal (étude des interactions entre perception et action (inférence active))
# * résumé des résultats attendus et de l'implication de ces résultats (briques stochastiques, ?? Les niveaux sont composés de briques de différentes couleurs auxquelles sont associés une probabilité de rebond ?? (dans intro ou dans méthodes ?))
#
# ## 2. Méthodes
# &nbsp;&nbsp;&nbsp;&nbsp;
# Afin de répondre à la problématique, nous avons choisi d'utiliser un jeu vidéo dont les paramètres sont aisément modifiables, un simple casse-briques. Le jeu est codé en Python, plus précisément avec le module Pygame, et permet de faire passer un sujet sur un set de niveaux tout en récoltant les données qui correspondent au déplacement de la balle ainsi que de la raquette. Les niveaux sont fait de manière à mettre en évidence l'apprentissage probabiliste inconscient que fait notre cerveau lorsqu'il reçoit des données probabilistes, et donc prédictibles dans une certaine mesure.
# &nbsp;&nbsp;&nbsp;&nbsp;
# Pour déterminer si le sujet observé apprend comme prévu, nous nous servons du mouvement de ses yeux grâce à un système d'eye-tracking, TheEyeTribe, et le corrélons au déplacement de la balle ainsi que de la raquette, ce dernier représentant les réactions du joueur car contrôlé par sa main via la souris. Nous nous sommes basé sur les travaux de Karl Friston, Rick A. Adams, Laurent Perrinet et Michael Breakspear dans leur papier *"Perceptions as hypotheses: saccades as experiments"* pour ce qui est du fait que le mouvement global de notre regard est le reflet des prédictions du cerveau, se traduisant dans notre cas par des saccades qui vont permettre au regard d'anticiper le déplacement de la balle lors d'un changement de direction.
# &nbsp;&nbsp;&nbsp;&nbsp;
# En effet, l'analyse du mouvement des yeux nous renseigne directement sur où se porte l'attention  du sujet et quelles sont les prédictions générées. On s'attend ainsi à observer différents comportements
#     * différents comportements
#     * on isole les sacades
#
# ## 3. Résultats
# * Résultats comportementaux => valide
# * évolution des latences de 1ère saccade après le rebond
# * synthèse des données en isolant les valeurs p
#
# ## 4. Discussion
# * Résumé des résultats obtenus
#     * jeu vidéo -> psycho
#     * analyse robuste
#     * marqueur psycho (latence) lié à la prédictabilité
# * limites
#     * variabilité des résulats du mouvement des yeux (regard périphérique) -> occlusion ?
#     * temps d'acquisition
#     * cadre théorique pour manipuler la valeur de prédictabilité
# * Ouvertures
#     * ?
#     * briques sociales
